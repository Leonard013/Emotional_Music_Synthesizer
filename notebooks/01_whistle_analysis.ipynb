# %% [markdown]
# # Whistle Analysis
#
# This notebook demonstrates how to analyze whistle audio and extract musical features.

# %%
import sys
sys.path.append('../src')

import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

from src.whistle_analysis import AudioProcessor, FeatureExtractor, PitchDetector
from src.inference import WhistleToMusicConverter

# %% [markdown]
# ## Load and Preprocess Whistle Audio

# %%
# Load whistle audio
whistle_path = "../data/whistles/example_whistle.wav"
audio, sr = librosa.load(whistle_path, sr=22050)

print(f"Audio duration: {len(audio) / sr:.2f} seconds")
print(f"Sample rate: {sr} Hz")
